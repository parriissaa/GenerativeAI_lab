# %%
# !pip install -r requirement.txt

# %%
# %%writefile .env
# OPENAI_API_KEY="Your OpenAI API KEY"
# Out:
# Overwriting .env

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# %%
import os.path
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

# either way we can now query the index
query_engine = index.as_query_engine()
response = query_engine.query("What is MultiFOLD?")
print(response)
# Out:
# MultiFOLD is a domain adaptation framework for offensive language detection that learns and adapts from multiple existing datasets (or source domains) to an unlabeled target domain. It employs a curriculum learning algorithm that starts learning with instances most similar to the target domain and gradually includes more distant instances. The model is trained with a standard task-specific loss and a domain adversarial objective to minimize language distinctions across multiple sources and the target, enabling the classifier to focus on distinguishing offensiveness rather than domain differences.
